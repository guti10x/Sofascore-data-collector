# %% [markdown]
# ### GET Clasificación
# ##### Devuelve la clasificación de todos los equiposen en Laliga.

# %%
import requests
import json

API_KEY = '81ff2da84493c8e2bef7f60395c6295c'
API_ENDPOINT = f'https://apiclient.besoccerapps.com/scripts/api/api.php?key={API_KEY}&format=json&req=tables&league=1&year=2023'

try:
    # Realizar la solicitud GET a la API
    response = requests.get(API_ENDPOINT)

    # Verificar si la solicitud fue exitosa (código de estado 200)
    if response.status_code == 200:
        # Obtener el JSON de la respuesta
        data = response.json()
        
        # Imprimir el JSON de forma legible
        print(json.dumps(data, indent=4))

        # Guardar el JSON en un archivo
        with open('clasificacion_equipos.json', 'w') as file:
            json.dump(data, file, indent=4)

        print('Archivo guardado exitosamente.')
    else:
        # Si la solicitud no fue exitosa, imprimir el código de estado
        print(f'Se produjo un error al hacer la solicitud. Código de estado: {response.status_code}')
except requests.exceptions.RequestException as e:
    # Manejar errores de solicitud
    print(f'Error al hacer la solicitud: {e}')
# Out:
# {
#     "table": [
#         {
#             "id": "429",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Barcelona",
#             "points": "88",
#             "wins": 28,
#             "draws": 4,
#             "losses": 6,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/429.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "barcelona",
#             "gf": "70",
#             "ga": "20",
#             "avg": 50,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 1,
#             "class_mark": "campeon",
#             "round": "38",
#             "pos": "1",
#             "countrycode": "ES",
#             "abbr": "FCB",
#             "form": "wllwl",
#             "direction": ""
#         },
#         {
#             "id": "2107",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Real Madrid",
#             "points": "78",
#             "wins": 24,
#             "draws": 6,
#             "losses": 8,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/2107.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "real-madrid",
#             "gf": "75",
#             "ga": "36",
#             "avg": 39,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 2,
#             "class_mark": "cha",
#             "round": "38",
#             "pos": "2",
#             "countrycode": "ES",
#             "abbr": "RMA",
#             "form": "wlwwd",
#             "direction": ""
#         },
#         {
#             "id": "369",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Atl\u00e9tico",
#             "points": "77",
#             "wins": 23,
#             "draws": 8,
#             "losses": 7,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/369.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "atletico-madrid",
#             "gf": "70",
#             "ga": "33",
#             "avg": 37,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 2,
#             "class_mark": "cha",
#             "round": "38",
#             "pos": "3",
#             "countrycode": "ES",
#             "abbr": "ATM",
#             "form": "lwdwd",
#             "direction": ""
#         },
#         {
#             "id": "2120",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Real Sociedad",
#             "points": "71",
#             "wins": 21,
#             "draws": 8,
#             "losses": 9,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/2120.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "real-sociedad",
#             "gf": "51",
#             "ga": "35",
#             "avg": 16,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 2,
#             "class_mark": "cha",
#             "round": "38",
#             "pos": "4",
#             "countrycode": "ES",
#             "abbr": "RSO",
#             "form": "dwwlw",
#             "direction": ""
#         },
#         {
#             "id": "2716",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Villarreal",
#             "points": "64",
#             "wins": 19,
#             "draws": 7,
#             "losses": 12,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/2716.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "villarreal",
#             "gf": "59",
#             "ga": "40",
#             "avg": 19,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 3,
#             "class_mark": "uefa",
#             "round": "38",
#             "pos": "5",
#             "countrycode": "ES",
#             "abbr": "VIL",
#             "form": "wwwld",
#             "direction": ""
#         },
#         {
#             "id": "486",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Real Betis",
#             "points": "60",
#             "wins": 17,
#             "draws": 9,
#             "losses": 12,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/486.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "betis",
#             "gf": "46",
#             "ga": "41",
#             "avg": 5,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 3,
#             "class_mark": "uefa",
#             "round": "38",
#             "pos": "6",
#             "countrycode": "ES",
#             "abbr": "BET",
#             "form": "wdlwd",
#             "direction": ""
#         },
#         {
#             "id": "1887",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Osasuna",
#             "points": "53",
#             "wins": 15,
#             "draws": 8,
#             "losses": 15,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/1887.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "osasuna",
#             "gf": "37",
#             "ga": "42",
#             "avg": -5,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 5,
#             "class_mark": "conf",
#             "round": "38",
#             "pos": "7",
#             "countrycode": "ES",
#             "abbr": "OSA",
#             "form": "wlwlw",
#             "direction": ""
#         },
#         {
#             "id": "347",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Athletic",
#             "points": "51",
#             "wins": 14,
#             "draws": 9,
#             "losses": 15,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/347.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "athletic-bilbao",
#             "gf": "47",
#             "ga": "43",
#             "avg": 4,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "8",
#             "countrycode": "ES",
#             "abbr": "ATH",
#             "form": "lwlld",
#             "direction": ""
#         },
#         {
#             "id": "1623",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Mallorca",
#             "points": "50",
#             "wins": 14,
#             "draws": 8,
#             "losses": 16,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/1623.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "mallorca",
#             "gf": "37",
#             "ga": "43",
#             "avg": -6,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "9",
#             "countrycode": "ES",
#             "abbr": "MLL",
#             "form": "wlwlw",
#             "direction": "u"
#         },
#         {
#             "id": "1236",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Girona",
#             "points": "49",
#             "wins": 13,
#             "draws": 10,
#             "losses": 15,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/1236.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "girona-fc",
#             "gf": "58",
#             "ga": "55",
#             "avg": 3,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "10",
#             "countrycode": "ES",
#             "abbr": "GIR",
#             "form": "dldll",
#             "direction": "d"
#         },
#         {
#             "id": "2080",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Rayo Vallecano",
#             "points": "49",
#             "wins": 13,
#             "draws": 10,
#             "losses": 15,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/2080.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "rayo-vallecano",
#             "gf": "45",
#             "ga": "53",
#             "avg": -8,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "11",
#             "countrycode": "ES",
#             "abbr": "RAY",
#             "form": "lllwl",
#             "direction": "d"
#         },
#         {
#             "id": "1102",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Sevilla",
#             "points": "49",
#             "wins": 13,
#             "draws": 10,
#             "losses": 15,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/1102.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "sevilla",
#             "gf": "47",
#             "ga": "54",
#             "avg": -7,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 2,
#             "class_mark": "cha",
#             "round": "38",
#             "pos": "12",
#             "countrycode": "ES",
#             "abbr": "SEV",
#             "form": "wddll",
#             "direction": "d"
#         },
#         {
#             "id": "712",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Celta",
#             "points": "43",
#             "wins": 11,
#             "draws": 10,
#             "losses": 17,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/712.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "celta",
#             "gf": "43",
#             "ga": "53",
#             "avg": -10,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "13",
#             "countrycode": "ES",
#             "abbr": "CEL",
#             "form": "lldlw",
#             "direction": "u"
#         },
#         {
#             "id": "603",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "C\u00e1diz",
#             "points": "42",
#             "wins": 10,
#             "draws": 12,
#             "losses": 16,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/603.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "cadiz",
#             "gf": "30",
#             "ga": "53",
#             "avg": -23,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "14",
#             "countrycode": "ES",
#             "abbr": "CAD",
#             "form": "lwlwd",
#             "direction": "d"
#         },
#         {
#             "id": "1217",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Getafe",
#             "points": "42",
#             "wins": 10,
#             "draws": 12,
#             "losses": 16,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/1217.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "getafe",
#             "gf": "34",
#             "ga": "45",
#             "avg": -11,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "15",
#             "countrycode": "ES",
#             "abbr": "GET",
#             "form": "ldwwd",
#             "direction": "d"
#         },
#         {
#             "id": "2647",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Valencia",
#             "points": "42",
#             "wins": 11,
#             "draws": 9,
#             "losses": 18,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/2647.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "valencia-cf",
#             "gf": "42",
#             "ga": "45",
#             "avg": -3,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "16",
#             "countrycode": "ES",
#             "abbr": "VCF",
#             "form": "wwldd",
#             "direction": "d"
#         },
#         {
#             "id": "183",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Almer\u00eda",
#             "points": "41",
#             "wins": 11,
#             "draws": 8,
#             "losses": 19,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/183.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "almeria",
#             "gf": "49",
#             "ga": "65",
#             "avg": -16,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": "",
#             "class_mark": "",
#             "round": "38",
#             "pos": "17",
#             "countrycode": "ES",
#             "abbr": "ALM",
#             "form": "lwldd",
#             "direction": "d"
#         },
#         {
#             "id": "2654",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Real Valladolid",
#             "points": "40",
#             "wins": 11,
#             "draws": 7,
#             "losses": 20,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/2654.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "valladolid",
#             "gf": "33",
#             "ga": "63",
#             "avg": -30,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 6,
#             "class_mark": "desc",
#             "round": "38",
#             "pos": "18",
#             "countrycode": "ES",
#             "abbr": "VAD",
#             "form": "llwdd",
#             "direction": ""
#         },
#         {
#             "id": "998",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Espanyol",
#             "points": "37",
#             "wins": 8,
#             "draws": 13,
#             "losses": 17,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/998.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "espanyol",
#             "gf": "52",
#             "ga": "69",
#             "avg": -17,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 6,
#             "class_mark": "desc",
#             "round": "38",
#             "pos": "19",
#             "countrycode": "ES",
#             "abbr": "ESP",
#             "form": "lwddd",
#             "direction": ""
#         },
#         {
#             "id": "975",
#             "group": "1",
#             "group_name": null,
#             "conference": "0",
#             "team": "Elche",
#             "points": "25",
#             "wins": 5,
#             "draws": 10,
#             "losses": 23,
#             "shield": "https://t.resfu.com/img_data/escudos/medium/975.jpg?size=120x&lossy=1&v=36",
#             "cflag": "https://t.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&lossy=1&v=36",
#             "basealias": "elche",
#             "gf": "30",
#             "ga": "67",
#             "avg": -37,
#             "matchs_coef": "",
#             "points_coef": "",
#             "coef": "",
#             "coefficients": null,
#             "mark": 6,
#             "class_mark": "desc",
#             "round": "38",
#             "pos": "20",
#             "countrycode": "ES",
#             "abbr": "ELC",
#             "form": "wddwd",
#             "direction": ""
#         }
#     ],
#     "info": {
#         "type": "Regular",
#         "type_id": "4"
#     },
#     "legends": [
#         {
#             "group": "1",
#             "legend": [
#                 {
#                     "pos": 1,
#                     "title": "Campe\u00f3n",
#                     "class_color": "campeon"
#                 },
#                 {
#                     "pos": 2,
#                     "title": "Champions League",
#                     "class_color": "cha"
#                 },
#                 {
#                     "pos": 3,
#                     "title": "Europa League",
#                     "class_color": "uefa"
#                 },
#                 {
#                     "pos": 5,
#                     "title": "Conference League",
#                     "class_color": "conf"
#                 },
#                 {
#                     "pos": 6,
#                     "title": "Descenso",
#                     "class_color": "desc"
#                 }
#             ],
#             "penalty": []
#         }
#     ]
# }
# Archivo guardado exitosamente.
